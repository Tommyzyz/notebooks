// %% [markdown]
// # F＃数据类型
//
// ## 整体数据类型
//
// 以下是根据您提供的信息转换成的Markdown表格：
//
// | F# 类型| 大小       | 范围                                             | 例子       | 备注                   |
// |--------|------------|--------------------------------------------------|-----------|------------------------|
// | sbyte  | 1个字节    | -128到127                                        | 42Y       | 8位有符号整数           |
// | byte   | 1个字节    | 0到255                                           | 42UY      | 8位无符号整数           |
// | int16  | 2个字节    | -32768到32767                                    | -42S      | 16位有符号整数          |
// | uint16 | 2个字节    | 0到65,535                                        | 42US      |  16位无符号整数         |
// | int32  | 4个字节    | -2,147,483,648到2,147,483,647                    | 42        |  32位有符号整数         |
// | uint32 | 4个字节    | 0到4,294,967,295                                 | 42U       | 32位无符号整数          |
// | int64  | 8个字节    | -9,223,372,036,854,775,808到9,223,372,036,854,775,807 |  -11L      |  64位有符号整数         |
// | uint64 | 8个字节    | 0到18,446,744,073,709,551,615                    |  200UL    |  64位无符号整数       |
// | bigint | 至少4个字节 | 任何整数                       | 14999999999999999999999999999999I     | 任意精度的整数          |
//
// ## 浮点数据类型
//
// | 类型         | 大小      | 范围                        | 例子       | 备注                               |
// |--------------|-----------|-----------------------------|------------|------------------------------------|
// | float32      | 4个字节   | ±1.5E-45至±3.4E38           | 42.0F      | 32位有符号浮点数（7个有效位）       |
// | float        | 8个字节   | ±5.0E-324到±1.7e308        | 42.0       | 64位有符号浮点数（15-16有效位）     |
// | decimal      | 16字节    | ±1.0E-28至±7.9e28          | 42.0M      | 128位有符号浮点数（28-29有效位）    |
// | BigRational  | 至少4个字节| 任意有理数                  | 42N        | 任意精度有理数。使用此类型需要引用FSharp.PowerPack.dll |
//
// ## text数据类型
//
// | F#类型 | 尺寸                          | 范围               | 例         | 备注                       |
// |--------|-------------------------------|--------------------|------------|----------------------------|
// | char   | 2个字节                       | U + 0000至U + FFFF | 'x'        | 单个Unicode字符            |
// | string | 20 +（2 *字符串的长度）个字节 | 0至约2十亿个字符   | "Hello"    | Unicode文本                |
//
// ## 其他数据类型
//
// | F#类型 | 尺寸    | 范围        | 例    | 备注  |
// |--------|---------|-------------|------|-------|
// | bool   | 1个字节 | true或false | true | 布尔值 |
