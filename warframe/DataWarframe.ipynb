// %%
// Root myDeserializedClass = JsonConvert.DeserializeObject<List<Root>>(myJsonResponse);
    public class Ability
    {
        public string uniqueName { get; set; }
        public string name { get; set; }
        public string description { get; set; }
    }

    public class Component
    {
        public string uniqueName { get; set; }
        public string name { get; set; }
        public string description { get; set; }
        public int itemCount { get; set; }
        public string imageName { get; set; }
        public bool tradable { get; set; }
        public bool masterable { get; set; }
        public List<Drop> drops { get; set; }
        public string type { get; set; }
        public int? primeSellingPrice { get; set; }
        public int? ducats { get; set; }
        public bool? excludeFromCodex { get; set; }
    }

    public class Drop
    {
        public double chance { get; set; }
        public string location { get; set; }
        public string rarity { get; set; }
        public string type { get; set; }
    }

    public class Introduced
    {
        public string name { get; set; }
        public string url { get; set; }
        public List<string> aliases { get; set; }
        public string parent { get; set; }
        public string date { get; set; }
    }

    public class Patchlog
    {
        public string name { get; set; }
        public DateTime date { get; set; }
        public string url { get; set; }
        public string additions { get; set; }
        public string changes { get; set; }
        public string fixes { get; set; }
    }

    public class WarframeData
    {
        public List<Ability> abilities { get; set; }
        public int armor { get; set; }
        public int buildPrice { get; set; }
        public int buildQuantity { get; set; }
        public int buildTime { get; set; }
        public string category { get; set; }
        public List<Component> components { get; set; }
        public bool consumeOnBuild { get; set; }
        public string description { get; set; }
        public int health { get; set; }
        public string imageName { get; set; }
        public bool isPrime { get; set; }
        public bool masterable { get; set; }
        public int masteryReq { get; set; }
        public string name { get; set; }
        public List<Patchlog> patchlogs { get; set; }
        public int power { get; set; }
        public string productCategory { get; set; }
        public int shield { get; set; }
        public int skipBuildTimePrice { get; set; }
        public double sprintSpeed { get; set; }
        public int stamina { get; set; }
        public bool tradable { get; set; }
        public string type { get; set; }
        public string uniqueName { get; set; }
        public string aura { get; set; }
        public int? bpCost { get; set; }
        public int? color { get; set; }
        public bool? conclave { get; set; }
        public Introduced introduced { get; set; }
        public int? marketCost { get; set; }
        public string passiveDescription { get; set; }
        public List<string> polarities { get; set; }
        public string releaseDate { get; set; }
        public string sex { get; set; }
        public double? sprint { get; set; }
        public string wikiaThumbnail { get; set; }
        public string wikiaUrl { get; set; }
        public string estimatedVaultDate { get; set; }
        public string vaultDate { get; set; }
        public bool? vaulted { get; set; }
        public List<string> exalted { get; set; }
    }

// %%
using System.Text.Json;
using System.Net.Http;
using System.Collections.Generic;

HttpClient httpClient=new();

var response = await httpClient.GetAsync("https://api.warframestat.us/warframes/");
var json = await response.Content.ReadAsStringAsync();
var result =  System.Text.Json.JsonSerializer.Deserialize<List<WarframeData>>(json);

result.Display();
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#2+WarframeData</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>abilities</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#2+Ability</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>uniqueName</td><td><div class="dni-plaintext"><pre>/Lotus/Powersuits/Archwing/ArchwingAbilities/SupportDronesAbility</pre></div></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>Watchful Swarm</pre></div></td></tr><tr><td>description</td><td><div class="dni-plaintext"><pre>Tiny drones orbit the Warframe or an ally, and intercept enemy fire.</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#2+Ability</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>uniqueName</td><td><div class="dni-plaintext"><pre>/Lotus/Powersuits/Archwing/ArchwingAbilities/SupportAnchorsAbility</pre></div></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>Benevolent Decoy</pre></div></td></tr><tr><td>description</td><td><div class="dni-plaintext"><pre>Creates beacons that draw enemy fire, converting the damage into healing pulses.</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#2+Ability</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>uniqueName</td><td><div class="dni-plaintext"><pre>/Lotus/Powersuits/Archwing/ArchwingAbilities/SupportWardAbility</pre></div></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>Warding Grace</pre></div></td></tr><tr><td>description</td><td><div class="dni-plaintext"><pre>Renders the Warframe and nearby allies immune to Status Effects, while slowing nearby enemies.</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#2+Ability</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>uniqueName</td><td><div class="dni-plaintext"><pre>/Lotus/Powersuits/Archwing/ArchwingAbilities/SupportEnergyAbility</pre></div></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>Vengeful Rush</pre></div></td></tr><tr><td>description</td><td><div class="dni-plaintext"><pre>All damage taken is transformed into Energy, while abilities gain enhanced Range, Duration and Power. Affects the Warframe and nearby allies.</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>armor</td><td><div class="dni-plaintext"><pre>195</pre></div></td></tr><tr><td>buildPrice</td><td><div class="dni-plaintext"><pre>25000</pre></div></td></tr><tr><td>buildQuantity</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>buildTime</td><td><div class="dni-plaintext"><pre>43200</pre></div></td></tr><tr><td>category</td><td><div class="dni-plaintext"><pre>Archwing</pre></div></td></tr><tr><td>components</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#2+Component</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>uniqueName</td><td><div class="dni-plaintext"><pre>/Lotus/Types/Recipes/ArchwingRecipes/SupportArchwing/SupportArchwingBlueprint</pre></div></td></tr><tr><td>name</td><td><div class="dni-plaintext"><pre>Blueprint</pre></div></td></tr><tr><td>description</td><td><div class="dni-plaintext"><pre>Transform into a winged guardian.</pre></div></td></tr><tr><td>itemCount</td><td><div ...
