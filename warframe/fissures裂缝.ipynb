// %%
// Root myDeserializedClass = JsonConvert.DeserializeObject<List<Root>>(myJsonResponse);
    public class fissures
    {
        public string id { get; set; }
        public DateTime activation { get; set; }
        public string startString { get; set; }
        public DateTime expiry { get; set; }
        public bool active { get; set; }
        public string node { get; set; }
        public string missionType { get; set; }
        public string missionKey { get; set; }
        public string enemy { get; set; }
        public string enemyKey { get; set; }
        public string nodeKey { get; set; }
        public string tier { get; set; }
        public int tierNum { get; set; }
        public bool expired { get; set; }
        public string eta { get; set; }
        public bool isStorm { get; set; }
        public bool isHard { get; set; }
    }

// %%
using System.Text.Json;
using System.Net.Http;
using System.Collections.Generic;

HttpClient httpClient=new();

var response = await httpClient.GetAsync("https://api.warframestat.us/pc/zh/fissures/");
var json = await response.Content.ReadAsStringAsync();
var result =  System.Text.Json.JsonSerializer.Deserialize<List<fissures>>(json);

result.Display();
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+fissures</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>64aa99c116e64ed2f9904982</td></tr><tr><td>activation</td><td><span>2023-07-09 11:28:01Z</span></td></tr><tr><td>startString</td><td>-1h 33m 48s</td></tr><tr><td>expiry</td><td><span>2023-07-09 13:08:43Z</span></td></tr><tr><td>active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>node</td><td>Anthe (土星)</td></tr><tr><td>missionType</td><td>救援</td></tr><tr><td>missionKey</td><td>Rescue</td></tr><tr><td>enemy</td><td>Grineer</td></tr><tr><td>enemyKey</td><td>Grineer</td></tr><tr><td>nodeKey</td><td>Anthe (Saturn)</td></tr><tr><td>tier</td><td>前纪</td></tr><tr><td>tierNum</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>expired</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>eta</td><td>6m 53s</td></tr><tr><td>isStorm</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>isHard</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+fissures</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>64aa99c116e64ed2f9904983</td></tr><tr><td>activation</td><td><span>2023-07-09 11:28:01Z</span></td></tr><tr><td>startString</td><td>-1h 33m 48s</td></tr><tr><td>expiry</td><td><span>2023-07-09 13:12:54Z</span></td></tr><tr><td>active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>node</td><td>Cinxia (穀神星)</td></tr><tr><td>missionType</td><td>攔截</td></tr><tr><td>missionKey</td><td>Interception</td></tr><tr><td>enemy</td><td>Grineer</td></tr><tr><td>enemyKey</td><td>Grineer</td></tr><tr><td>nodeKey</td><td>Cinxia (Ceres)</td></tr><tr><td>tier</td><td>前纪</td></tr><tr><td>tierNum</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>expired</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>eta</td><td>11m 4s</td></tr><tr><td>isStorm</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>isHard</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+fissures</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>64aa9bdde8f1f922ab548ba1</td></tr><tr><td>activation</td><td><span>2023-07-09 11:37:01Z</span></td></tr><tr><td>startString</td><td>-1h 24m 48s</td></tr><tr><td>expiry</td><td><span>2023-07-09 13:05:09Z</span></td></tr><tr><td>active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>node</td><td>Hydron (賽德娜)</td></tr><tr><td>missionType</td><td>防禦</td></tr><tr><td>missionKey</td><td>Defense</td></tr><tr><td>enemy</td><td>Grineer</td></tr><tr><td>enemyKey</td><td>Grineer</td></tr><tr><td>nodeKey</td><td>Hydron (Sedna)</td></tr><tr><td>tier</td><td>后纪</td></tr><tr><td>tierNum</td><td><div class="dni-plaintext"><pre>4</pre></div></td></tr><tr><td>expired</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>eta</td><td>3m 20s</td></tr><tr><td>isStorm</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>isHard</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+fissures</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>64aa9bdde8f1f922ab548ba2</td></tr><tr><td>activation</td><td><span>2023-07-09 11:37:01Z</span></td></tr><tr><td>startString</td><td>-1h 24m 48s</td></tr ...
