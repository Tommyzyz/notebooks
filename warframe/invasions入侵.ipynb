// %%
// Root myDeserializedClass = JsonConvert.DeserializeObject<List<Root>>(myJsonResponse);
    public class Attacker
    {
        public Reward reward { get; set; }
        public string faction { get; set; }
        public string factionKey { get; set; }
    }

    public class AttackerReward
    {
        public List<object> items { get; set; }
        public List<CountedItem> countedItems { get; set; }
        public int credits { get; set; }
        public string asString { get; set; }
        public string itemString { get; set; }
        public string thumbnail { get; set; }
        public int color { get; set; }
    }

    public class CountedItem
    {
        public int count { get; set; }
        public string type { get; set; }
        public string key { get; set; }
    }

    public class Defender
    {
        public Reward reward { get; set; }
        public string faction { get; set; }
        public string factionKey { get; set; }
    }

    public class DefenderReward
    {
        public List<object> items { get; set; }
        public List<CountedItem> countedItems { get; set; }
        public int credits { get; set; }
        public string asString { get; set; }
        public string itemString { get; set; }
        public string thumbnail { get; set; }
        public int color { get; set; }
    }

    public class Reward
    {
        public List<object> items { get; set; }
        public List<CountedItem> countedItems { get; set; }
        public int credits { get; set; }
        public string asString { get; set; }
        public string itemString { get; set; }
        public string thumbnail { get; set; }
        public int color { get; set; }
    }

    public class invasions
    {
        public string id { get; set; }
        public DateTime activation { get; set; }
        public string startString { get; set; }
        public string node { get; set; }
        public string nodeKey { get; set; }
        public string desc { get; set; }
        public AttackerReward attackerReward { get; set; }
        public string attackingFaction { get; set; }
        public Attacker attacker { get; set; }
        public DefenderReward defenderReward { get; set; }
        public string defendingFaction { get; set; }
        public Defender defender { get; set; }
        public bool vsInfestation { get; set; }
        public int count { get; set; }
        public int requiredRuns { get; set; }
        public double completion { get; set; }
        public bool completed { get; set; }
        public string eta { get; set; }
        public List<string> rewardTypes { get; set; }
    }

// %%
using System.Text.Json;
using System.Net.Http;
using System.Collections.Generic;

HttpClient httpClient=new();

var response = await httpClient.GetAsync("https://api.warframestat.us/pc/zh/invasions/");
var json = await response.Content.ReadAsStringAsync();
var result =  System.Text.Json.JsonSerializer.Deserialize<List<invasions>>(json);

result.Display();
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+invasions</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>64a438a15c82690bba01da1f</td></tr><tr><td>activation</td><td><span>2023-07-05 11:25:53Z</span></td></tr><tr><td>startString</td><td>-4d 1h 42m 56s</td></tr><tr><td>node</td><td>Naga (賽德娜)</td></tr><tr><td>nodeKey</td><td>Naga (Sedna)</td></tr><tr><td>desc</td><td>Corpus Siege</td></tr><tr><td>attackerReward</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+AttackerReward</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>items</td><td></td></tr><tr><td>countedItems</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+CountedItem</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>count</td><td><div class="dni-plaintext"><pre>3</pre></div></td></tr><tr><td>type</td><td>电磁力场装置</td></tr><tr><td>key</td><td>Fieldron</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>credits</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>asString</td><td>3 电磁力场装置</td></tr><tr><td>itemString</td><td>3 电磁力场装置</td></tr><tr><td>thumbnail</td><td>https://i.imgur.com/qlrlfft.png</td></tr><tr><td>color</td><td><div class="dni-plaintext"><pre>5068118</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>attackingFaction</td><td>Corpus</td></tr><tr><td>attacker</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+Attacker</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>reward</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+Reward</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>items</td><td></td></tr><tr><td>countedItems</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+CountedItem</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>count</td><td>3</td></tr><tr><td>type</td><td>电磁力场装置</td></tr><tr><td>key</td><td>Fieldron</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>credits</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>asString</td><td>3 电磁力场装置</td></tr><tr><td>itemString</td><td>3 电磁力场装置</td></tr><tr><td>thumbnail</td><td>https://i.imgur.com/qlrlfft.png</td></tr><tr><td>color</td><td><div class="dni-plaintext"><pre>5068118</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>faction</td><td>Corpus</td></tr><tr><td>factionKey</td><td>Corpus</td></tr></tbody></table></div></details></td></tr><tr><td>defenderReward</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+DefenderReward</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>items</td><td></td></tr><tr><td>countedItems</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+CountedItem</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>count</td><td><div class="dni-plaintext"><pre>3</pre></div></td></tr><tr><td>type</td><td>爆燃喷射器</td></tr><tr><td>key</td><td>Detonite Injector</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>credits</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>asString</td><td>3 爆燃喷射器</td></tr><tr><td>itemString</td><td>3 爆燃喷射器</td></tr><tr><td>thumbnail</td><td>https://i.imgur.com/rV6 ...
