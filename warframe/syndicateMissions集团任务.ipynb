// %% [markdown]
// Ostrons: 地球赏金
// Solaris: 金星赏金
// EntratiSyndicate: 火卫二赏金

// %%
// Root myDeserializedClass = JsonConvert.DeserializeObject<List<Root>>(myJsonResponse);
    public class Job
    {
        public string id { get; set; }
        public List<string> rewardPool { get; set; }
        public string type { get; set; }
        public List<int> enemyLevels { get; set; }
        public List<int> standingStages { get; set; }
        public int minMR { get; set; }
        public DateTime expiry { get; set; }
        public string timeBound { get; set; }
        public bool? isVault { get; set; }
        public string locationTag { get; set; }
        public string timeBoound { get; set; }
    }

    public class syndicateMissions
    {
        public string id { get; set; }
        public DateTime activation { get; set; }
        public string startString { get; set; }
        public DateTime expiry { get; set; }
        public bool active { get; set; }
        public string syndicate { get; set; }
        public string syndicateKey { get; set; }
        public List<string> nodes { get; set; }
        public List<Job> jobs { get; set; }
        public string eta { get; set; }
    }

// %%
using System.Text.Json;
using System.Net.Http;
using System.Collections.Generic;

HttpClient httpClient=new();

var response = await httpClient.GetAsync("https://api.warframestat.us/pc/zh/syndicateMissions/");
var json = await response.Content.ReadAsStringAsync();
var result =  System.Text.Json.JsonSerializer.Deserialize<List<syndicateMissions>>(json);

result.Display();
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+syndicateMissions</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>1688910523850CetusSyndicate</td></tr><tr><td>activation</td><td><span>2023-07-09 11:18:44Z</span></td></tr><tr><td>startString</td><td>-1h 12m 5s</td></tr><tr><td>expiry</td><td><span>2023-07-09 13:48:43Z</span></td></tr><tr><td>active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>syndicate</td><td>Ostrons</td></tr><tr><td>syndicateKey</td><td>Ostrons</td></tr><tr><td>nodes</td><td></td></tr><tr><td>jobs</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+Job</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>AttritionBountySab1688910523850</td></tr><tr><td>rewardPool</td><td><div class="dni-plaintext"><pre>[ Vitality, 200X Plastids, 1,500 Credits Cache, 50 Endo, 15X Nistlepod, Gara Chassis Blueprint, Point Blank, Intensify, 2X Gallium ]</pre></div></td></tr><tr><td>type</td><td>Sabotage the Enemy Supply Lines</td></tr><tr><td>enemyLevels</td><td><div class="dni-plaintext"><pre>[ 5, 15 ]</pre></div></td></tr><tr><td>standingStages</td><td><div class="dni-plaintext"><pre>[ 400, 400, 400 ]</pre></div></td></tr><tr><td>minMR</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>expiry</td><td><span>2023-07-09 13:48:43Z</span></td></tr><tr><td>timeBound</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>isVault</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>locationTag</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>timeBoound</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+Job</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>AttritionBountyLib1688910523850</td></tr><tr><td>rewardPool</td><td><div class="dni-plaintext"><pre>[ Point Strike, 300X Circuits, 2,500 Credits Cache, 100 Endo, Gara Systems Blueprint, Enhanced Durability, Grim Fury, Aya, 2X Orokin Cell ]</pre></div></td></tr><tr><td>type</td><td>Weaken the Grineer Foothold</td></tr><tr><td>enemyLevels</td><td><div class="dni-plaintext"><pre>[ 10, 30 ]</pre></div></td></tr><tr><td>standingStages</td><td><div class="dni-plaintext"><pre>[ 590, 590, 590 ]</pre></div></td></tr><tr><td>minMR</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>expiry</td><td><span>2023-07-09 13:48:43Z</span></td></tr><tr><td>timeBound</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>isVault</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>locationTag</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>timeBoound</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#3+Job</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>id</td><td>AttritionBountyExt1688910523850</td></tr><tr><td>rewardPool</td><td><div class="dni-plaintext"><pre>[ Augur Pact, Naramon Lens, Zenurik Lens, 200 Endo, Gara Neuroptics Blueprint, Vigilante Fervor, Revenant Systems Blueprint, Aya, Gladiator Vice ]</pre></div></td></tr><tr><td>type</td><td>Cull the Enemy</td></tr><tr><td>enemyLevels</td><td><div class="dni-plaintext"><pre>[ 20, 40 ]</pre></div></td></tr><tr><td>standingStages</td><td><div class="dni-plaintext"><pre>[ 670, 670, 670, 990 ]</pr ...
