// %%
// rivens
using System.Text.Json;
// Root myDeserializedClass = JsonConvert.DeserializeObject<Root>(myJsonResponse);
    public class Acceltra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class AckBrunt
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Acrid
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Aegrit
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Aeolak
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Afentis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Afuris
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Akarius
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Akbolto
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Akbronco
    {
        public Unrolled unrolled { get; set; }
    }

    public class Akjagara
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Aklato
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Aklex
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Akmagnus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Aksomati
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Akstiletto
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Akvasto
    {
        public Unrolled unrolled { get; set; }
    }

    public class Akzani
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Alternox
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ambassador
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Amphis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Amprex
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Angstrum
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Anku
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ankyros
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ArcaPlasmor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ArcaScisco
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ArcaTitron
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ArchgunRivenMod
    {
        public Cortege Cortege { get; set; }
        public Corvas Corvas { get; set; }
        public Cyngas Cyngas { get; set; }

        [JsonProperty("Dual Decurion")]
        public DualDecurion DualDecurion { get; set; }
        public Fluctus Fluctus { get; set; }
        public Grattler Grattler { get; set; }
        public Imperator Imperator { get; set; }

        [JsonProperty("Kuva Ayanga")]
        public KuvaAyanga KuvaAyanga { get; set; }
        public Larkspur Larkspur { get; set; }
        public Mausolon Mausolon { get; set; }
        public Morgha Morgha { get; set; }
        public Phaedra Phaedra { get; set; }
        public Velocitus Velocitus { get; set; }
    }

    public class Argonak
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Artax
    {
        public Unrolled unrolled { get; set; }
    }

    public class ArumSpinosa
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Astilla
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Athodai
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Atomos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Atterax
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Attica
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Azima
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Azothane
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Balla
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ballistica
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Basmu
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Battacor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Baza
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Bo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Boar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Boltace
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Bolto
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Boltor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Brakk
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Braton
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class BrokenScepter
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class BrokenWar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Bronco
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Bubonico
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Burston
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Buzlok
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cadus
    {
        public Unrolled unrolled { get; set; }
    }

    public class Cassowar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Castanas
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Catabolyst
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Catchmoon
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Caustacyst
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cedo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class CeramicDagger
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cerata
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cernos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cestra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cinta
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class CobraCrane
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Convectrix
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Corinth
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cortege
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Corufell
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Corvas
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cronus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cryotra
    {
        public Unrolled unrolled { get; set; }
    }

    public class Cyanex
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cyath
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cycron
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Cyngas
    {
        public Rerolled rerolled { get; set; }
    }

    public class Daikyu
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DakraPrime
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DarkDagger
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DarkSplitSword
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DarkSword
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Deconstructor
    {
        public Unrolled unrolled { get; set; }
    }

    public class Dehtat
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Dera
    {
        public Unrolled unrolled { get; set; }
    }

    public class Despair
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Destreza
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DethMachineRifle
    {
        public Unrolled unrolled { get; set; }
    }

    public class Detron
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DexDakra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Dokrahm
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DragonNikana
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Drakgoon
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Dread
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualCestra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualCleavers
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualDecurion
    {
        public Rerolled rerolled { get; set; }
    }

    public class DualEther
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualHeatSwords
    {
        public Unrolled unrolled { get; set; }
    }

    public class DualIchor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualKamas
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualKeres
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualRaza
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualSkana
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualToxocyst
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class DualZoren
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Edun
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Embolist
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Endura
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Epitaph
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class EtherDaggers
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class EtherReaper
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class EtherSword
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class EuphonaPrime
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Exergis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Falcor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Fang
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Felarx
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ferrox
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Fluctus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class FluxRifle
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Fragor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Fulmin
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Furax
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Furis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Fusilai
    {
        public Unrolled unrolled { get; set; }
    }

    public class Galatine
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Galvacord
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Gammacor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class GazalMachete
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Gaze
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ghoulsaw
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Glaive
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Glaxion
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Gorgon
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Grakata
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Gram
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Grattler
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Grinlok
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Guandao
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Gunsen
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Halikar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Harpak
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hate
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class HeatDagger
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class HeatSword
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hek
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Heliocor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Helstrum
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hema
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hespar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hikou
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hind
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hirudo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Hystrix
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ignis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Imperator
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Innodem
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class JatKittag
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class JatKusar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Javlok
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class JawSword
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kama
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Karak
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Karyst
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Keratinos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kesheg
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kestrel
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class KitgunRivenMod
    {
        [JsonProperty("Veiled Kitgun Riven Mod")]
        public VeiledKitgunRivenMod VeiledKitgunRivenMod { get; set; }
        public Catchmoon Catchmoon { get; set; }
        public Gaze Gaze { get; set; }
        public Rattleguts Rattleguts { get; set; }
        public Sporelacer Sporelacer { get; set; }
        public Tombfinger Tombfinger { get; set; }
        public Vermisplicer Vermisplicer { get; set; }
    }

    public class Knell
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kogake
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kohm
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kohmak
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Komorex
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kompressa
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Korrudo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Korumm
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kraken
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kreska
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Krohkur
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kronen
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kronsh
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kulstar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Kunai
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class KuvaAyanga
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class KuvaBramma
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class KuvaChakkhurr
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class KuvaShildeg
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class KuvaTwinStubbas
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lacera
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lacerten
    {
        public Rerolled rerolled { get; set; }
    }

    public class Laetum
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lanka
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Larkspur
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lato
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Latron
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lecta
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lenz
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lesion
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Lex
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Machete
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Magistar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Magnus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Marelok
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Masseter
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Mausolon
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class MeleeRivenMod
    {
        [JsonProperty("Veiled Melee Riven Mod")]
        public VeiledMeleeRivenMod VeiledMeleeRivenMod { get; set; }

        [JsonProperty("Ack & Brunt")]
        public AckBrunt AckBrunt { get; set; }
        public Amphis Amphis { get; set; }
        public Anku Anku { get; set; }
        public Ankyros Ankyros { get; set; }

        [JsonProperty("Arca Titron")]
        public ArcaTitron ArcaTitron { get; set; }

        [JsonProperty("Arum Spinosa")]
        public ArumSpinosa ArumSpinosa { get; set; }
        public Atterax Atterax { get; set; }
        public Azothane Azothane { get; set; }
        public Bo Bo { get; set; }
        public Boltace Boltace { get; set; }

        [JsonProperty("Broken Scepter")]
        public BrokenScepter BrokenScepter { get; set; }

        [JsonProperty("Broken War")]
        public BrokenWar BrokenWar { get; set; }
        public Cadus Cadus { get; set; }
        public Cassowar Cassowar { get; set; }
        public Caustacyst Caustacyst { get; set; }

        [JsonProperty("Ceramic Dagger")]
        public CeramicDagger CeramicDagger { get; set; }
        public Cerata Cerata { get; set; }

        [JsonProperty("Cobra & Crane")]
        public CobraCrane CobraCrane { get; set; }
        public Corufell Corufell { get; set; }
        public Cronus Cronus { get; set; }

        [JsonProperty("Dakra Prime")]
        public DakraPrime DakraPrime { get; set; }

        [JsonProperty("Dark Dagger")]
        public DarkDagger DarkDagger { get; set; }

        [JsonProperty("Dark Split-Sword")]
        public DarkSplitSword DarkSplitSword { get; set; }

        [JsonProperty("Dark Sword")]
        public DarkSword DarkSword { get; set; }
        public Deconstructor Deconstructor { get; set; }
        public Destreza Destreza { get; set; }

        [JsonProperty("Dex Dakra")]
        public DexDakra DexDakra { get; set; }

        [JsonProperty("Dragon Nikana")]
        public DragonNikana DragonNikana { get; set; }

        [JsonProperty("Dual Cleavers")]
        public DualCleavers DualCleavers { get; set; }

        [JsonProperty("Dual Ether")]
        public DualEther DualEther { get; set; }

        [JsonProperty("Dual Heat Swords")]
        public DualHeatSwords DualHeatSwords { get; set; }

        [JsonProperty("Dual Ichor")]
        public DualIchor DualIchor { get; set; }

        [JsonProperty("Dual Kamas")]
        public DualKamas DualKamas { get; set; }

        [JsonProperty("Dual Keres")]
        public DualKeres DualKeres { get; set; }

        [JsonProperty("Dual Raza")]
        public DualRaza DualRaza { get; set; }

        [JsonProperty("Dual Skana")]
        public DualSkana DualSkana { get; set; }

        [JsonProperty("Dual Zoren")]
        public DualZoren DualZoren { get; set; }
        public Edun Edun { get; set; }
        public Endura Endura { get; set; }

        [JsonProperty("Ether Daggers")]
        public EtherDaggers EtherDaggers { get; set; }

        [JsonProperty("Ether Reaper")]
        public EtherReaper EtherReaper { get; set; }

        [JsonProperty("Ether Sword")]
        public EtherSword EtherSword { get; set; }
        public Falcor Falcor { get; set; }
        public Fang Fang { get; set; }
        public Fragor Fragor { get; set; }
        public Furax Furax { get; set; }
        public Galatine Galatine { get; set; }
        public Galvacord Galvacord { get; set; }

        [JsonProperty("Gazal Machete")]
        public GazalMachete GazalMachete { get; set; }
        public Ghoulsaw Ghoulsaw { get; set; }
        public Glaive Glaive { get; set; }
        public Gram Gram { get; set; }
        public Guandao Guandao { get; set; }
        public Gunsen Gunsen { get; set; }
        public Halikar Halikar { get; set; }
        public Hate Hate { get; set; }

        [JsonProperty("Heat Dagger")]
        public HeatDagger HeatDagger { get; set; }

        [JsonProperty("Heat Sword")]
        public HeatSword HeatSword { get; set; }
        public Heliocor Heliocor { get; set; }
        public Hespar Hespar { get; set; }
        public Hirudo Hirudo { get; set; }
        public Innodem Innodem { get; set; }

        [JsonProperty("Jat Kittag")]
        public JatKittag JatKittag { get; set; }

        [JsonProperty("Jat Kusar")]
        public JatKusar JatKusar { get; set; }

        [JsonProperty("Jaw Sword")]
        public JawSword JawSword { get; set; }
        public Kama Kama { get; set; }
        public Karyst Karyst { get; set; }
        public Keratinos Keratinos { get; set; }
        public Kesheg Kesheg { get; set; }
        public Kestrel Kestrel { get; set; }
        public Kogake Kogake { get; set; }
        public Korrudo Korrudo { get; set; }
        public Korumm Korumm { get; set; }
        public Kreska Kreska { get; set; }
        public Krohkur Krohkur { get; set; }
        public Kronen Kronen { get; set; }

        [JsonProperty("Kuva Shildeg")]
        public KuvaShildeg KuvaShildeg { get; set; }
        public Lacera Lacera { get; set; }
        public Lacerten Lacerten { get; set; }
        public Lecta Lecta { get; set; }
        public Lesion Lesion { get; set; }
        public Machete Machete { get; set; }
        public Magistar Magistar { get; set; }
        public Masseter Masseter { get; set; }
        public Mios Mios { get; set; }
        public Mire Mire { get; set; }

        [JsonProperty("Nami Skyla")]
        public NamiSkyla NamiSkyla { get; set; }

        [JsonProperty("Nami Solo")]
        public NamiSolo NamiSolo { get; set; }
        public Nepheri Nepheri { get; set; }
        public Nikana Nikana { get; set; }
        public Ninkondi Ninkondi { get; set; }
        public Obex Obex { get; set; }
        public Ohma Ohma { get; set; }
        public Okina Okina { get; set; }
        public Orthos Orthos { get; set; }
        public Orvius Orvius { get; set; }

        [JsonProperty("Pangolin Sword")]
        public PangolinSword PangolinSword { get; set; }
        public Paracesis Paracesis { get; set; }
        public Pathocyst Pathocyst { get; set; }
        public Pennant Pennant { get; set; }

        [JsonProperty("Plasma Sword")]
        public PlasmaSword PlasmaSword { get; set; }
        public Praedos Praedos { get; set; }
        public Prova Prova { get; set; }
        public Pulmonars Pulmonars { get; set; }
        public Pupacyst Pupacyst { get; set; }
        public Quassus Quassus { get; set; }

        [JsonProperty("Reaper Prime")]
        public ReaperPrime ReaperPrime { get; set; }
        public Redeemer Redeemer { get; set; }
        public Ripkas Ripkas { get; set; }
        public Rumblejack Rumblejack { get; set; }
        public Sampotes Sampotes { get; set; }
        public Sarofang Sarofang { get; set; }
        public Sarpa Sarpa { get; set; }
        public Scindo Scindo { get; set; }
        public Scoliac Scoliac { get; set; }
        public Serro Serro { get; set; }
        public Shaku Shaku { get; set; }
        public Sheev Sheev { get; set; }
        public Sibear Sibear { get; set; }

        [JsonProperty("Sigma & Octantis")]
        public SigmaOctantis SigmaOctantis { get; set; }

        [JsonProperty("Silva & Aegis")]
        public SilvaAegis SilvaAegis { get; set; }
        public Skana Skana { get; set; }
        public Skiajati Skiajati { get; set; }
        public Slaytra Slaytra { get; set; }
        public Stropha Stropha { get; set; }

        [JsonProperty("Sun & Moon")]
        public SunMoon SunMoon { get; set; }
        public Syam Syam { get; set; }
        public Sydon Sydon { get; set; }
        public Tatsu Tatsu { get; set; }
        public Tekko Tekko { get; set; }

        [JsonProperty("Tenet Agendus")]
        public TenetAgendus TenetAgendus { get; set; }

        [JsonProperty("Tenet Exec")]
        public TenetExec TenetExec { get; set; }

        [JsonProperty("Tenet Grigori")]
        public TenetGrigori TenetGrigori { get; set; }

        [JsonProperty("Tenet Livia")]
        public TenetLivia TenetLivia { get; set; }
        public Tipedo Tipedo { get; set; }
        public Tonbo Tonbo { get; set; }

        [JsonProperty("Twin Basolk")]
        public TwinBasolk TwinBasolk { get; set; }

        [JsonProperty("Twin Krohkur")]
        public TwinKrohkur TwinKrohkur { get; set; }
        public Vastilok Vastilok { get; set; }
        public Venato Venato { get; set; }
        public Venka Venka { get; set; }
        public Verdilac Verdilac { get; set; }
        public Vericres Vericres { get; set; }
        public Vitrica Vitrica { get; set; }
        public Volnus Volnus { get; set; }
        public War War { get; set; }

        [JsonProperty("Wolf Sledge")]
        public WolfSledge WolfSledge { get; set; }
        public Xoris Xoris { get; set; }
        public Zenistar Zenistar { get; set; }
    }

    public class Mewan
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Mios
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Mire
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Miter
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Morgha
    {
        public Unrolled unrolled { get; set; }
    }

    public class MutalistCernos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class MutalistQuanta
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Nagantaka
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class NamiSkyla
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class NamiSolo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Nataruk
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Nepheri
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Nikana
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ninkondi
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Nukor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Obex
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ocucor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ogris
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Ohma
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Okina
    {
        public Unrolled unrolled { get; set; }
    }

    public class Ooltha
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Opticor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Orthos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Orvius
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Pandero
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class PangolinSword
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Panthera
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Paracesis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Paracyst
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Paris
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Pathocyst
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Pennant
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Penta
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Perigale
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Phaedra
    {
        public Unrolled unrolled { get; set; }
    }

    public class Phage
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Phantasma
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Phenmor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class PistolRivenMod
    {
        [JsonProperty("Veiled Pistol Riven Mod")]
        public VeiledPistolRivenMod VeiledPistolRivenMod { get; set; }
        public Acrid Acrid { get; set; }
        public Aegrit Aegrit { get; set; }
        public Afuris Afuris { get; set; }
        public Akarius Akarius { get; set; }
        public Akbolto Akbolto { get; set; }
        public Akbronco Akbronco { get; set; }
        public Akjagara Akjagara { get; set; }
        public Aklato Aklato { get; set; }
        public Aklex Aklex { get; set; }
        public Akmagnus Akmagnus { get; set; }
        public Aksomati Aksomati { get; set; }
        public Akstiletto Akstiletto { get; set; }
        public Akvasto Akvasto { get; set; }
        public Akzani Akzani { get; set; }
        public Angstrum Angstrum { get; set; }

        [JsonProperty("Arca Scisco")]
        public ArcaScisco ArcaScisco { get; set; }
        public Athodai Athodai { get; set; }
        public Atomos Atomos { get; set; }
        public Azima Azima { get; set; }
        public Ballistica Ballistica { get; set; }
        public Bolto Bolto { get; set; }
        public Brakk Brakk { get; set; }
        public Bronco Bronco { get; set; }
        public Castanas Castanas { get; set; }
        public Catabolyst Catabolyst { get; set; }
        public Cestra Cestra { get; set; }
        public Cyanex Cyanex { get; set; }
        public Cycron Cycron { get; set; }
        public Despair Despair { get; set; }
        public Detron Detron { get; set; }

        [JsonProperty("Dual Cestra")]
        public DualCestra DualCestra { get; set; }

        [JsonProperty("Dual Toxocyst")]
        public DualToxocyst DualToxocyst { get; set; }
        public Embolist Embolist { get; set; }
        public Epitaph Epitaph { get; set; }

        [JsonProperty("Euphona Prime")]
        public EuphonaPrime EuphonaPrime { get; set; }
        public Furis Furis { get; set; }
        public Fusilai Fusilai { get; set; }
        public Gammacor Gammacor { get; set; }
        public Hikou Hikou { get; set; }
        public Hystrix Hystrix { get; set; }
        public Knell Knell { get; set; }
        public Kohmak Kohmak { get; set; }
        public Kompressa Kompressa { get; set; }
        public Kraken Kraken { get; set; }
        public Kulstar Kulstar { get; set; }
        public Kunai Kunai { get; set; }

        [JsonProperty("Kuva Twin Stubbas")]
        public KuvaTwinStubbas KuvaTwinStubbas { get; set; }
        public Laetum Laetum { get; set; }
        public Lato Lato { get; set; }
        public Lex Lex { get; set; }
        public Magnus Magnus { get; set; }
        public Marelok Marelok { get; set; }
        public Nukor Nukor { get; set; }
        public Ocucor Ocucor { get; set; }
        public Pandero Pandero { get; set; }
        public Plinx Plinx { get; set; }
        public Pox Pox { get; set; }
        public Pyrana Pyrana { get; set; }
        public Quatz Quatz { get; set; }
        public Seer Seer { get; set; }
        public Sepulcrum Sepulcrum { get; set; }
        public Sicarus Sicarus { get; set; }
        public Sonicor Sonicor { get; set; }
        public Spectra Spectra { get; set; }
        public Spira Spira { get; set; }
        public Staticor Staticor { get; set; }
        public Stubba Stubba { get; set; }
        public Stug Stug { get; set; }
        public Talons Talons { get; set; }

        [JsonProperty("Tenet Diplos")]
        public TenetDiplos TenetDiplos { get; set; }

        [JsonProperty("Tenet Spirex")]
        public TenetSpirex TenetSpirex { get; set; }

        [JsonProperty("Twin Grakatas")]
        public TwinGrakatas TwinGrakatas { get; set; }

        [JsonProperty("Twin Gremlins")]
        public TwinGremlins TwinGremlins { get; set; }

        [JsonProperty("Twin Kohmak")]
        public TwinKohmak TwinKohmak { get; set; }

        [JsonProperty("Twin Rogga")]
        public TwinRogga TwinRogga { get; set; }

        [JsonProperty("Twin Vipers")]
        public TwinVipers TwinVipers { get; set; }
        public Tysis Tysis { get; set; }
        public Vasto Vasto { get; set; }
        public Velox Velox { get; set; }
        public Viper Viper { get; set; }
        public Zakti Zakti { get; set; }
        public Zylok Zylok { get; set; }
        public Zymos Zymos { get; set; }
    }

    public class PlagueKeewar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class PlagueKripath
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class PlasmaSword
    {
        public Unrolled unrolled { get; set; }
    }

    public class Plinx
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Pox
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Praedos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ProboscisCernos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Prova
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Pulmonars
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Pupacyst
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Pyrana
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Quanta
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Quartakk
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Quassus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Quatz
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Quellor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Rabvee
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Rattleguts
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Rauta
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ReaperPrime
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Redeemer
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Rerolled
    {
        public string itemType { get; set; }
        public string compatibility { get; set; }
        public bool rerolled { get; set; }
        public double avg { get; set; }
        public double stddev { get; set; }
        public int min { get; set; }
        public int max { get; set; }
        public int pop { get; set; }
        public int median { get; set; }
    }

    public class RifleRivenMod
    {
        [JsonProperty("Veiled Rifle Riven Mod")]
        public VeiledRifleRivenMod VeiledRifleRivenMod { get; set; }
        public Acceltra Acceltra { get; set; }
        public Aeolak Aeolak { get; set; }
        public Afentis Afentis { get; set; }
        public Alternox Alternox { get; set; }
        public Ambassador Ambassador { get; set; }
        public Amprex Amprex { get; set; }
        public Argonak Argonak { get; set; }
        public Artax Artax { get; set; }
        public Attica Attica { get; set; }
        public Basmu Basmu { get; set; }
        public Battacor Battacor { get; set; }
        public Baza Baza { get; set; }
        public Boltor Boltor { get; set; }
        public Braton Braton { get; set; }
        public Burston Burston { get; set; }
        public Buzlok Buzlok { get; set; }
        public Cernos Cernos { get; set; }
        public Cinta Cinta { get; set; }
        public Cryotra Cryotra { get; set; }
        public Daikyu Daikyu { get; set; }
        public Dera Dera { get; set; }

        [JsonProperty("Deth Machine Rifle")]
        public DethMachineRifle DethMachineRifle { get; set; }
        public Dread Dread { get; set; }
        public Ferrox Ferrox { get; set; }

        [JsonProperty("Flux Rifle")]
        public FluxRifle FluxRifle { get; set; }
        public Fulmin Fulmin { get; set; }
        public Glaxion Glaxion { get; set; }
        public Gorgon Gorgon { get; set; }
        public Grakata Grakata { get; set; }
        public Grinlok Grinlok { get; set; }
        public Harpak Harpak { get; set; }
        public Helstrum Helstrum { get; set; }
        public Hema Hema { get; set; }
        public Hind Hind { get; set; }
        public Ignis Ignis { get; set; }
        public Javlok Javlok { get; set; }
        public Karak Karak { get; set; }
        public Komorex Komorex { get; set; }

        [JsonProperty("Kuva Bramma")]
        public KuvaBramma KuvaBramma { get; set; }

        [JsonProperty("Kuva Chakkhurr")]
        public KuvaChakkhurr KuvaChakkhurr { get; set; }
        public Lanka Lanka { get; set; }
        public Latron Latron { get; set; }
        public Lenz Lenz { get; set; }
        public Miter Miter { get; set; }

        [JsonProperty("Mutalist Cernos")]
        public MutalistCernos MutalistCernos { get; set; }

        [JsonProperty("Mutalist Quanta")]
        public MutalistQuanta MutalistQuanta { get; set; }
        public Nagantaka Nagantaka { get; set; }
        public Nataruk Nataruk { get; set; }
        public Ogris Ogris { get; set; }
        public Opticor Opticor { get; set; }
        public Panthera Panthera { get; set; }
        public Paracyst Paracyst { get; set; }
        public Paris Paris { get; set; }
        public Penta Penta { get; set; }
        public Perigale Perigale { get; set; }
        public Phenmor Phenmor { get; set; }

        [JsonProperty("Proboscis Cernos")]
        public ProboscisCernos ProboscisCernos { get; set; }
        public Quanta Quanta { get; set; }
        public Quartakk Quartakk { get; set; }
        public Quellor Quellor { get; set; }
        public Rubico Rubico { get; set; }
        public Scourge Scourge { get; set; }
        public Shedu Shedu { get; set; }
        public Simulor Simulor { get; set; }
        public Snipetron Snipetron { get; set; }
        public Soma Soma { get; set; }
        public Sporothrix Sporothrix { get; set; }
        public Stahlta Stahlta { get; set; }
        public Stinger Stinger { get; set; }
        public Stradavar Stradavar { get; set; }
        public Supra Supra { get; set; }
        public Sybaris Sybaris { get; set; }
        public Synapse Synapse { get; set; }

        [JsonProperty("Tenet Envoy")]
        public TenetEnvoy TenetEnvoy { get; set; }
        public Tenora Tenora { get; set; }
        public Tetra Tetra { get; set; }
        public Tiberon Tiberon { get; set; }
        public Tonkor Tonkor { get; set; }
        public Torid Torid { get; set; }
        public Trumna Trumna { get; set; }
        public Vectis Vectis { get; set; }
        public Veldt Veldt { get; set; }
        public Verglas Verglas { get; set; }
        public Vulkar Vulkar { get; set; }
        public Vulklok Vulklok { get; set; }
        public Zarr Zarr { get; set; }
        public Zenith Zenith { get; set; }
        public Zhuge Zhuge { get; set; }
    }

    public class Ripkas
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class rivens
    {
        [JsonProperty("Kitgun Riven Mod")]
        public KitgunRivenMod KitgunRivenMod { get; set; }

        [JsonProperty("Melee Riven Mod")]
        public MeleeRivenMod MeleeRivenMod { get; set; }

        [JsonProperty("Pistol Riven Mod")]
        public PistolRivenMod PistolRivenMod { get; set; }

        [JsonProperty("Rifle Riven Mod")]
        public RifleRivenMod RifleRivenMod { get; set; }

        [JsonProperty("Shotgun Riven Mod")]
        public ShotgunRivenMod ShotgunRivenMod { get; set; }

        [JsonProperty("Zaw Riven Mod")]
        public ZawRivenMod ZawRivenMod { get; set; }

        [JsonProperty("Archgun Riven Mod")]
        public ArchgunRivenMod ArchgunRivenMod { get; set; }
    }

    public class Rubico
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Rumblejack
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sampotes
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sarofang
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sarpa
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Scindo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Scoliac
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Scourge
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Seer
    {
        public Unrolled unrolled { get; set; }
    }

    public class Sepfahn
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sepulcrum
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Serro
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Shaku
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Shedu
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sheev
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ShotgunRivenMod
    {
        [JsonProperty("Veiled Shotgun Riven Mod")]
        public VeiledShotgunRivenMod VeiledShotgunRivenMod { get; set; }

        [JsonProperty("Arca Plasmor")]
        public ArcaPlasmor ArcaPlasmor { get; set; }
        public Astilla Astilla { get; set; }
        public Boar Boar { get; set; }
        public Bubonico Bubonico { get; set; }
        public Cedo Cedo { get; set; }
        public Convectrix Convectrix { get; set; }
        public Corinth Corinth { get; set; }
        public Drakgoon Drakgoon { get; set; }
        public Exergis Exergis { get; set; }
        public Felarx Felarx { get; set; }
        public Hek Hek { get; set; }
        public Kohm Kohm { get; set; }
        public Phage Phage { get; set; }
        public Phantasma Phantasma { get; set; }
        public Rauta Rauta { get; set; }
        public Sobek Sobek { get; set; }
        public Steflos Steflos { get; set; }
        public Strun Strun { get; set; }
        public Sweeper Sweeper { get; set; }
        public Tigris Tigris { get; set; }
    }

    public class Sibear
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sicarus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class SigmaOctantis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class SilvaAegis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Simulor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Skana
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Skiajati
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Slaytra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Snipetron
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sobek
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Soma
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sonicor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Spectra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Spira
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sporelacer
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sporothrix
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Stahlta
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Staticor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Steflos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Stinger
    {
        public Unrolled unrolled { get; set; }
    }

    public class Stradavar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Stropha
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Strun
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Stubba
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Stug
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class SunMoon
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Supra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sweeper
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Syam
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sybaris
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Sydon
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Synapse
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Talons
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tatsu
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tekko
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TenetAgendus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TenetDiplos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TenetEnvoy
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TenetExec
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TenetGrigori
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TenetLivia
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TenetSpirex
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tenora
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tetra
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tiberon
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tigris
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tipedo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tombfinger
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tonbo
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tonkor
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Torid
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Trumna
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TwinBasolk
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TwinGrakatas
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TwinGremlins
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TwinKohmak
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TwinKrohkur
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TwinRogga
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class TwinVipers
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Tysis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Unrolled
    {
        public string itemType { get; set; }
        public string compatibility { get; set; }
        public bool rerolled { get; set; }
        public double avg { get; set; }
        public double stddev { get; set; }
        public int min { get; set; }
        public int max { get; set; }
        public int pop { get; set; }
        public int median { get; set; }
    }

    public class Vastilok
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Vasto
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Vectis
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class VeiledKitgunRivenMod
    {
        public Unrolled unrolled { get; set; }
    }

    public class VeiledMeleeRivenMod
    {
        public Unrolled unrolled { get; set; }
    }

    public class VeiledPistolRivenMod
    {
        public Unrolled unrolled { get; set; }
    }

    public class VeiledRifleRivenMod
    {
        public Unrolled unrolled { get; set; }
    }

    public class VeiledShotgunRivenMod
    {
        public Unrolled unrolled { get; set; }
    }

    public class VeiledZawRivenMod
    {
        public Unrolled unrolled { get; set; }
    }

    public class Veldt
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Velocitus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Velox
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Venato
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Venka
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Verdilac
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Verglas
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Vericres
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Vermisplicer
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Viper
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Vitrica
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Volnus
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Vulkar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Vulklok
    {
        public Unrolled unrolled { get; set; }
    }

    public class War
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class WolfSledge
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Xoris
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Zakti
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Zarr
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class ZawRivenMod
    {
        [JsonProperty("Veiled Zaw Riven Mod")]
        public VeiledZawRivenMod VeiledZawRivenMod { get; set; }
        public Balla Balla { get; set; }
        public Cyath Cyath { get; set; }
        public Dehtat Dehtat { get; set; }
        public Dokrahm Dokrahm { get; set; }
        public Kronsh Kronsh { get; set; }
        public Mewan Mewan { get; set; }
        public Ooltha Ooltha { get; set; }

        [JsonProperty("Plague Keewar")]
        public PlagueKeewar PlagueKeewar { get; set; }

        [JsonProperty("Plague Kripath")]
        public PlagueKripath PlagueKripath { get; set; }
        public Rabvee Rabvee { get; set; }
        public Sepfahn Sepfahn { get; set; }
    }

    public class Zenistar
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Zenith
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Zhuge
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Zylok
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }

    public class Zymos
    {
        public Rerolled rerolled { get; set; }
        public Unrolled unrolled { get; set; }
    }
// Out:
// (176,10): error CS0616: “JsonProperty”不是特性类
//
// (182,10): error CS0616: “JsonProperty”不是特性类
//
// (1041,10): error CS0616: “JsonProperty”不是特性类
//
// (1274,10): error CS0616: “JsonProperty”不是特性类
//
// (1277,10): error CS0616: “JsonProperty”不是特性类
//
// (1283,10): error CS0616: “JsonProperty”不是特性类
//
// (1286,10): error CS0616: “JsonProperty”不是特性类
//
// (1293,10): error CS0616: “JsonProperty”不是特性类
//
// (1296,10): error CS0616: “JsonProperty”不是特性类
//
// (1302,10): error CS0616: “JsonProperty”不是特性类
//
// (1306,10): error CS0616: “JsonProperty”不是特性类
//
// (1311,10): error CS0616: “JsonProperty”不是特性类
//
// (1314,10): error CS0616: “JsonProperty”不是特性类
//
// (1317,10): error CS0616: “JsonProperty”不是特性类
//
// (1320,10): error CS0616: “JsonProperty”不是特性类
//
// (1325,10): error CS0616: “JsonProperty”不是特性类
//
// (1328,10): error CS0616: “JsonProperty”不是特性类
//
// (1331,10): error CS0616: “JsonProperty”不是特性类
//
// (1334,10): error CS0616: “JsonProperty”不是特性类
//
// ...

// %%
using System.Text.Json;
using System.Net.Http;
using System.Collections.Generic;

HttpClient httpClient=new();

var response = await httpClient.GetAsync("https://api.warframestat.us/pc/zh/rivens/");
var json = await response.Content.ReadAsStringAsync();
var result =  System.Text.Json.JsonSerializer.Deserialize<rivens>(json);

result.Display();
// Out:
// (9,59): error CS0246: 未能找到类型或命名空间名“rivens”(是否缺少 using 指令或程序集引用?)
